# %% [markdown]
# # Word Batch

# %%
import csv
import math
import re
from abc import abstractmethod, ABC
from collections import Counter

import numpy as np

np.random.seed(99)

# %% [markdown]
# ## Foundation

# %% [markdown]
# ### Tensor

# %%
class Tensor:

    def __init__(self, data):
        self.data = np.array(data)
        self.grad = None
        self.gradient_fn = lambda: None
        self.parents = set()

    def backward(self):
        if self.gradient_fn:
            self.gradient_fn()

        for p in self.parents:
            p.backward()

    def shape(self):
        return self.data.shape

    def size(self):
        return np.prod(self.data.shape[1:])

    def __str__(self):
        return str(self.data)

# %% [markdown]
# ### Base Dataset

# %%
class Dataset(ABC):

    def __init__(self, batch_size=1):
        self.batch_size = batch_size
        self.load()
        self.train()

    @abstractmethod
    def load(self):
        pass

    def train(self):
        self.features = self.train_features
        self.labels = self.train_labels

    def eval(self):
        self.features = self.test_features
        self.labels = self.test_labels

    def shape(self):
        return Tensor(self.features).size(), Tensor(self.labels).size()

    def items(self):
        return Tensor(self.features), Tensor(self.labels)

    def __len__(self):
        return len(self.features) // self.batch_size

    def __getitem__(self, index):
        start = index * self.batch_size
        end = start + self.batch_size
        return Tensor(self.features[start: end]), Tensor(self.labels[start: end])

    @abstractmethod
    def estimate(self, predictions):
        pass

# %% [markdown]
# ### Base Layer

# %%
class Layer(ABC):

    def __init__(self):
        self.training = True

    def __call__(self, x: Tensor):
        return self.forward(x)

    def train(self):
        self.training = True

    def eval(self):
        self.training = False

    @abstractmethod
    def forward(self, x: Tensor):
        pass

    def parameters(self):
        return []

    def __str__(self):
        return ''

# %% [markdown]
# ### Base Loss Function

# %%
class Loss(ABC):

    @abstractmethod
    def __call__(self, p: Tensor, y: Tensor):
        pass

# %% [markdown]
# ### Base Optimizer

# %%
class Optimizer(ABC):

    def __init__(self, parameters, lr):
        self.parameters = parameters
        self.lr = lr

    @abstractmethod
    def backward(self):
        pass

# %% [markdown]
# ### Base Model

# %%
class Model(ABC):

    def __init__(self, layer, loss, optimizer):
        self.layer = layer
        self.loss = loss
        self.optimizer = optimizer

    @abstractmethod
    def train(self, dataset, epochs):
        pass

    @abstractmethod
    def test(self, dataset):
        pass

# %% [markdown]
# ## Data

# %% [markdown]
# ### RNN Dataset

# %%
class RNNDataset(Dataset):

    def __init__(self, filename):
        self.filename = filename
        super().__init__()

    def load(self):
        self.reviews = []
        self.sentiments = []
        with open(self.filename, 'r', encoding='utf-8') as f:
            reader = csv.reader(f)
            next(reader)
            for _, row in enumerate(reader):
                self.reviews.append(row[0])
                self.sentiments.append(row[1])

        split_reviews = []
        for line in self.reviews:
            split_reviews.append(self.clean_text(line.lower()).split())

        self.vocabulary = set(word for line in split_reviews for word in line)
        self.word2index = {word: index for index, word in enumerate(self.vocabulary)}
        self.index2word = {index: word for index, word in enumerate(self.vocabulary)}
        self.tokens = [[self.word2index[word] for word in line if word in self.word2index] for line in split_reviews]

    @staticmethod
    def clean_text(text):
        text = re.sub(r'<[^>]+>', '', text)
        text = re.sub(r'[^a-zA-Z0-9\s]', '', text)
        return text

    def train(self):
        self.features = []
        self.labels = []
        for line in self.tokens[:-10]:
            for index in range(len(line) - 4):
                self.features.append(line[index: index + 4])
                self.labels.append(self.onehot(line[index + 4]))
    def eval(self):
        self.features = []
        self.labels = []
        for line in self.tokens[-10:]:
            for index in range(len(line) - 4):
                self.features.append(line[index: index + 4])
                self.labels.append(self.onehot(line[index + 4]))

    def encode(self, text):
        words = self.clean_text(text.lower()).split()
        return [self.word2index[word] for word in words]

    def decode(self, tokens):
        return " ".join([self.index2word[index] for index in tokens])

    def onehot(self, token):
        ebd = np.zeros(len(self.vocabulary))
        ebd[token] = 1
        return ebd

    @staticmethod
    def argmax(vector):
        return [np.argmax(vector)]

    def estimate(self, predictions):
        count = 0
        for i in range(len(predictions)):
            if self.argmax(predictions[i].data[0]) == self.argmax(self.labels[i].data):
                count += 1
        return count / len(predictions)

# %% [markdown]
# ## Model

# %% [markdown]
# ### Linear Layer

# %%
class Linear(Layer):

    def __init__(self, in_size, out_size):
        super().__init__()
        self.weight = Tensor(np.random.rand(out_size, in_size) / in_size)
        self.bias = Tensor(np.zeros(out_size))

    def forward(self, x: Tensor):
        p = Tensor(x.data @ self.weight.data.T + self.bias.data)

        def gradient_fn():
            self.weight.grad = p.grad.T @ x.data / len(x.data)
            self.bias.grad = np.sum(p.grad, axis=0) / len(x.data)
            x.grad = p.grad @ self.weight.data

        p.gradient_fn = gradient_fn
        p.parents = {self.weight, self.bias, x}
        return p

    def parameters(self):
        return [self.weight, self.bias]

    def __str__(self):
        return f'weight: {self.weight}\nbias: {self.bias}'

# %% [markdown]
# ### Sequential Layer

# %%
class Sequential(Layer):

    def __init__(self, layers):
        super().__init__()
        self.layers = layers

    def train(self):
        for l in self.layers:
            l.train()

    def eval(self):
        for l in self.layers:
            l.eval()

    def forward(self, x: Tensor):
        for l in self.layers:
            x = l(x)
        return x

    def parameters(self):
        return [p for l in self.layers for p in l.parameters()]

    def __str__(self):
        return '\n'.join(str(l) for l in self.layers if str(l))

# %% [markdown]
# ### Embedding Layer

# %%
class Embedding(Layer):

    def __init__(self, vocabulary_size, embedding_size, axis=1):
        super().__init__()
        self.vocabulary_size = vocabulary_size
        self.embedding_size = embedding_size
        self.axis = axis

        self.weight = Tensor(np.random.rand(embedding_size, vocabulary_size) / vocabulary_size)

    def forward(self, x: Tensor):
        p = Tensor(np.sum(self.weight.data.T[x.data], axis=self.axis))

        def gradient_fn():
            if self.weight.grad is None:
                self.weight.grad = np.zeros_like(self.weight.data)
            self.weight.grad.T[x.data] += p.grad

        p.gradient_fn = gradient_fn
        p.parents = {self.weight}
        return p

    def parameters(self):
        return [self.weight]

# %% [markdown]
# ### ReLU Activation Function

# %%
class ReLU(Layer):

    def forward(self, x: Tensor):
        p = Tensor(np.maximum(0, x.data))

        def gradient_fn():
            x.grad = (p.data > 0) * p.grad

        p.gradient_fn = gradient_fn
        p.parents = {x}
        return p

# %% [markdown]
# ### Tanh Activation Function

# %%
class Tanh(Layer):

    def forward(self, x: Tensor):
        p = Tensor(np.tanh(x.data))

        def gradient_fn():
            x.grad = p.grad * (1 - p.data ** 2)

        p.gradient_fn = gradient_fn
        p.parents = {x}
        return p

# %% [markdown]
# ### Sigmoid Activation Function

# %%
class Sigmoid(Layer):

    def __init__(self, clip_range=(-100, 100)):
        super().__init__()
        self.clip_range = clip_range

    def forward(self, x: Tensor):
        z = np.clip(x.data, self.clip_range[0], self.clip_range[1])
        p = Tensor(1 / (1 + np.exp(-z)))

        def gradient_fn():
            x.grad = p.grad * p.data * (1 - p.data)

        p.gradient_fn = gradient_fn
        p.parents = {x}
        return p

# %% [markdown]
# ### Softmax Activation Function

# %%
class Softmax(Layer):

    def __init__(self, axis=1):
        super().__init__()
        self.axis = axis

    def forward(self, x: Tensor):
        exp = np.exp(x.data - np.max(x.data, axis=self.axis, keepdims=True))
        p = Tensor(exp / np.sum(exp, axis=self.axis, keepdims=True))

        def gradient_fn():
            x.grad = np.zeros_like(x.data)
            for idx in range(x.data.shape[0]):
                itm = p.data[idx].reshape(-1, 1)
                x.grad[idx] = (np.diagflat(itm) - itm @ itm.T) @ p.grad[idx]

        p.gradient_fn = gradient_fn
        p.parents = {x}
        return p

# %% [markdown]
# ### MSE Loss Function

# %%
class MSELoss(Loss):

    def __call__(self, p: Tensor, y: Tensor):
        mse = Tensor(((p.data - y.data) ** 2).mean())

        def gradient_fn():
            p.grad = (p.data - y.data) * 2

        mse.gradient_fn = gradient_fn
        mse.parents = {p}
        return mse

# %% [markdown]
# ### Cross Entropy Loss Function

# %%
class CELoss:

    def __call__(self, p: Tensor, y: Tensor):
        exp = np.exp(p.data - np.max(p.data, axis=-1, keepdims=True))
        softmax = exp / np.sum(exp, axis=-1, keepdims=True)

        log = np.log(np.clip(softmax, 1e-10, 1))
        ce = Tensor(0 - np.sum(y.data * log) / len(p.data))

        def gradient_fn():
            p.grad = (softmax - y.data) / len(p.data)

        ce.gradient_fn = gradient_fn
        ce.parents = {p}
        return ce

# %% [markdown]
# ### Binary Cross Entropy Loss Function

# %%
class BCELoss:

    def __call__(self, p: Tensor, y: Tensor):
        clipped = np.clip(p.data, 1e-7, 1 - 1e-7)
        bce = Tensor(-np.mean(y.data * np.log(clipped)
                              + (1 - y.data) * np.log(1 - clipped)))

        def gradient_fn():
            p.grad = (clipped - y.data) / (clipped * (1 - clipped)) * len(p.data)

        bce.gradient_fn = gradient_fn
        bce.parents = {p}
        return bce

# %% [markdown]
# ### SGD Optimizer

# %%
class SGDOptimizer(Optimizer):

    def backward(self):
        for p in self.parameters:
            p.data -= p.grad * self.lr

# %% [markdown]
# ### Recurrent Neural Network Model

# %%
class RNNModel(Model):

    def train(self, dataset, epochs):
        layer.train()
        dataset.train()

        for epoch in range(epochs):
            for i in range(len(dataset)):
                features, labels = dataset[i]

                predictions = self.layer(features)
                error = self.loss(predictions,
                                  labels)

                error.backward()
                self.optimizer.backward()

    def test(self, dataset):
        layer.eval()
        dataset.eval()

        predictions = []
        for i in range(len(dataset)):
            feature, label = dataset[i]
            predictions.append(self.layer(feature))
        return predictions

# %% [markdown]
# ## Configuration

# %% [markdown]
# ### Learning Rate

# %%
LEARNING_RATE = 0.01

# %% [markdown]
# ### Epoch

# %%
EPOCHS = 10

# %% [markdown]
# ## Training

# %% [markdown]
# ### Iteration Training

# %%
dataset = RNNDataset('reviews.csv')
layer = Sequential([Embedding(len(dataset.vocabulary), 64),
                    Tanh(),
                    Linear(64, 16),
                    Tanh(),
                    Linear(16, len(dataset.vocabulary))])
loss = CELoss()
optimizer = SGDOptimizer(layer.parameters(),
                         lr=LEARNING_RATE)

model = RNNModel(layer,
                 loss,
                 optimizer)
model.train(dataset,
            EPOCHS)

# %% [markdown]
# ## Testing

# %% [markdown]
# ### Estimating

# %%
predictions = model.test(dataset)

print(f'Accuracy: {dataset.estimate(predictions)}')
# Out:
# Accuracy: 0.28662420382165604

# %% [markdown]
# ### Comparing Labels and Predictions

# %%
features, labels = dataset.items()
for i in range(len(predictions)):
    pos = np.argmax(predictions[i].data[0])
    print(f'Feature: {dataset.decode(features.data[i])} | '
          f'Label: {dataset.decode(dataset.argmax(labels.data[i]))} | '
          f'Prediction: {dataset.decode(dataset.argmax(predictions[i].data[0]))}')
# Out:
# Feature: worst movie with awful | Label: music | Prediction: the
# Feature: movie with awful music | Label: the | Prediction: the
# Feature: with awful music the | Label: actor | Prediction: director
# Feature: awful music the actor | Label: did | Prediction: director
# Feature: music the actor did | Label: a | Prediction: a
# Feature: the actor did a | Label: boring | Prediction: director
# Feature: actor did a boring | Label: job | Prediction: job
# Feature: did a boring job | Label: actress | Prediction: director
# Feature: a boring job actress | Label: director | Prediction: director
# Feature: boring job actress director | Label: character | Prediction: actress
# Feature: job actress director character | Label: screenplay | Prediction: scene
# Feature: actress director character screenplay | Label: scene | Prediction: plot
# Feature: director character screenplay scene | Label: but | Prediction: plot
# Feature: character screenplay scene but | Label: or | Prediction: was
# Feature: screenplay scene but or | Label: it | Prediction: in
# Feature: scene but or it | Label: at | Prediction: a
# Feature: but or it at | Label: by | Prediction: in
# Feature: i recommend this film | Label: the | Prediction: the
# Feature: recommend this film the | Label: actress | Prediction: and
# Feature: this film the actress | Label: was | Prediction: was
# Feature: film the actress was | Label: wonderful | Prediction: director
# Feature: the actress was wonderful | Label: and | Prediction: director
# Feature: actress was wonderful and | Label: the | Prediction: the
# Feature: was wonderful and the | Label: music | Prediction: was
# Feature: wonderful and the music | Label: was | Prediction: was
# Feature: and the music was | Label: amazing | Prediction: was
# Feature: the music was amazing | Label: actor | Prediction: director
# Feature: music was amazing actor | Label: director | Prediction: scene
# Feature: was amazing actor director | Label: character | Prediction: actress
# Feature: amazing actor director character | Label: scene | Prediction: plot
# Feature: actor director character scene | Label: plot | Prediction: plot
# Feature: director character scene plot | Label: by | Prediction: plot
# Feature: character scene plot by | Label: was | Prediction: plot
# Feature: poor movie the story | Label: and | Prediction: and
# Feature: movie the story and | Label: actor | Prediction: was
# Feature: the story and actor | Label: were | Prediction: was
# Feature: story and actor were | Label: terrible | Prediction: the
# Feature: and actor were terrible | Label: i | Prediction: i
# Feature: actor were terrible i | Label: disappointed | Prediction: i
# Feature: were terrible i disappointed | Label: the | Prediction: the
# Feature: terrible i disappointed the | Label: director | Prediction: and
# Feature: i disappointed the director | Label: actress | Prediction: director
# Feature: disappointed the director actress | Label: character | Prediction: actress
# Feature: the director actress character | Label: action | Prediction: plot
# Feature: director actress character action | Label: screenplay | Prediction: screenplay
# Feature: actress character action screenplay | Label: scene | Prediction: job
# Feature: character action screenplay scene | Label: by | Prediction: job
# Feature: action screenplay scene by | Label: is | Prediction: plot
# Feature: excellent film i saw | Label: this | Prediction: the
# Feature: film i saw this | Label: time | Prediction: by
# Feature: i saw this time | Label: perfect | Prediction: by
# Feature: saw this time perfect | Label: performance | Prediction: by
# Feature: this time perfect performance | Label: by | Prediction: by
# Feature: time perfect performance by | Label: the | Prediction: the
# Feature: perfect performance by the | Label: actor | Prediction: and
# Feature: performance by the actor | Label: and | Prediction: and
# Feature: by the actor and | Label: actress | Prediction: and
# Feature: the actor and actress | Label: director | Prediction: was
# Feature: actor and actress director | Label: screenplay | Prediction: scene
# Feature: and actress director screenplay | Label: scene | Prediction: scene
# Feature: actress director screenplay scene | Label: character | Prediction: plot
# Feature: director screenplay scene character | Label: his | Prediction: plot
# Feature: screenplay scene character his | Label: her | Prediction: by
# Feature: boring movie with poor | Label: effect | Prediction: the
# Feature: movie with poor effect | Label: the | Prediction: the
# Feature: with poor effect the | Label: director | Prediction: director
# Feature: poor effect the director | Label: did | Prediction: actress
# Feature: effect the director did | Label: a | Prediction: a
# Feature: the director did a | Label: awful | Prediction: director
# Feature: director did a awful | Label: job | Prediction: job
# Feature: did a awful job | Label: actor | Prediction: director
# Feature: a awful job actor | Label: character | Prediction: director
# Feature: awful job actor character | Label: actress | Prediction: actress
# Feature: job actor character actress | Label: screenplay | Prediction: actress
# Feature: actor character actress screenplay | Label: music | Prediction: plot
# Feature: character actress screenplay music | Label: plot | Prediction: by
# Feature: actress screenplay music plot | Label: by | Prediction: by
# Feature: screenplay music plot by | Label: was | Prediction: at
# Feature: music plot by was | Label: is | Prediction: at
# Feature: this film was wonderful | Label: i | Prediction: i
# Feature: film was wonderful i | Label: loved | Prediction: the
# Feature: was wonderful i loved | Label: the | Prediction: the
# Feature: wonderful i loved the | Label: plot | Prediction: and
# Feature: i loved the plot | Label: and | Prediction: and
# Feature: loved the plot and | Label: actress | Prediction: was
# Feature: the plot and actress | Label: the | Prediction: was
# Feature: plot and actress the | Label: scene | Prediction: was
# Feature: and actress the scene | Label: was | Prediction: was
# Feature: actress the scene was | Label: amazing | Prediction: director
# Feature: the scene was amazing | Label: director | Prediction: director
# Feature: scene was amazing director | Label: character | Prediction: character
# Feature: was amazing director character | Label: actor | Prediction: character
# Feature: amazing director character actor | Label: screenplay | Prediction: plot
# Feature: director character actor screenplay | Label: his | Prediction: plot
# Feature: character actor screenplay his | Label: her | Prediction: job
# Feature: great movie the actor | Label: and | Prediction: and
# Feature: movie the actor and | Label: screenplay | Prediction: was
# Feature: the actor and screenplay | Label: were | Prediction: was
# Feature: actor and screenplay were | Label: excellent | Prediction: the
# Feature: and screenplay were excellent | Label: i | Prediction: i
# Feature: screenplay were excellent i | Label: enjoyed | Prediction: the
# Feature: were excellent i enjoyed | Label: the | Prediction: the
# Feature: excellent i enjoyed the | Label: visual | Prediction: and
# Feature: i enjoyed the visual | Label: actress | Prediction: and
# Feature: enjoyed the visual actress | Label: character | Prediction: director
# Feature: the visual actress character | Label: scene | Prediction: director
# Feature: visual actress character scene | Label: script | Prediction: plot
# Feature: actress character scene script | Label: music | Prediction: plot
# Feature: character scene script music | Label: effect | Prediction: was
# Feature: scene script music effect | Label: or | Prediction: was
# Feature: i waste of time | Label: the | Prediction: the
# Feature: waste of time the | Label: screenplay | Prediction: was
# Feature: of time the screenplay | Label: was | Prediction: was
# Feature: time the screenplay was | Label: boring | Prediction: actor
# Feature: the screenplay was boring | Label: and | Prediction: director
# Feature: screenplay was boring and | Label: the | Prediction: the
# Feature: was boring and the | Label: scene | Prediction: was
# Feature: boring and the scene | Label: was | Prediction: was
# Feature: and the scene was | Label: awful | Prediction: was
# Feature: the scene was awful | Label: actor | Prediction: director
# Feature: scene was awful actor | Label: actress | Prediction: character
# Feature: was awful actor actress | Label: character | Prediction: actress
# Feature: awful actor actress character | Label: screenplay | Prediction: plot
# Feature: actor actress character screenplay | Label: music | Prediction: plot
# Feature: actress character screenplay music | Label: effect | Prediction: by
# Feature: character screenplay music effect | Label: by | Prediction: by
# Feature: best film with fantastic | Label: soundtrack | Prediction: the
# Feature: film with fantastic soundtrack | Label: the | Prediction: the
# Feature: with fantastic soundtrack the | Label: director | Prediction: director
# Feature: fantastic soundtrack the director | Label: did | Prediction: actress
# Feature: soundtrack the director did | Label: a | Prediction: a
# Feature: the director did a | Label: perfect | Prediction: director
# Feature: director did a perfect | Label: job | Prediction: job
# Feature: did a perfect job | Label: actor | Prediction: director
# Feature: a perfect job actor | Label: actress | Prediction: director
# Feature: perfect job actor actress | Label: character | Prediction: actress
# Feature: job actor actress character | Label: scene | Prediction: actress
# Feature: actor actress character scene | Label: screenplay | Prediction: plot
# Feature: actress character scene screenplay | Label: music | Prediction: screenplay
# Feature: character scene screenplay music | Label: in | Prediction: by
# Feature: scene screenplay music in | Label: on | Prediction: by
# Feature: this movie was terrible | Label: i | Prediction: i
# Feature: movie was terrible i | Label: hated | Prediction: the
# Feature: was terrible i hated | Label: the | Prediction: the
# Feature: terrible i hated the | Label: story | Prediction: and
# Feature: i hated the story | Label: and | Prediction: and
# Feature: hated the story and | Label: actor | Prediction: was
# Feature: the story and actor | Label: the | Prediction: was
# Feature: story and actor the | Label: scene | Prediction: was
# Feature: and actor the scene | Label: was | Prediction: was
# Feature: actor the scene was | Label: poor | Prediction: director
# Feature: the scene was poor | Label: actress | Prediction: director
# Feature: scene was poor actress | Label: director | Prediction: scene
# Feature: was poor actress director | Label: character | Prediction: scene
# Feature: poor actress director character | Label: screenplay | Prediction: plot
# Feature: actress director character screenplay | Label: action | Prediction: plot
# Feature: director character screenplay action | Label: by | Prediction: screenplay

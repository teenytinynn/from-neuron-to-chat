# %% [markdown]
# # Word Batch

# %%
import csv
import math
import re
from abc import abstractmethod, ABC
from collections import Counter

import numpy as np

np.random.seed(99)

# %% [markdown]
# ## Foundation

# %% [markdown]
# ### Tensor

# %%
class Tensor:

    def __init__(self, data):
        self.data = np.array(data)
        self.grad = None
        self.gradient_fn = lambda: None
        self.parents = set()

    def backward(self):
        if self.gradient_fn:
            self.gradient_fn()

        for p in self.parents:
            p.backward()

    def shape(self):
        return self.data.shape

    def size(self):
        return np.prod(self.data.shape[1:])

    def __str__(self):
        return str(self.data)

# %% [markdown]
# ### Base Dataset

# %%
class Dataset(ABC):

    def __init__(self, batch_size=1):
        self.batch_size = batch_size
        self.load()
        self.train()

    @abstractmethod
    def load(self):
        pass

    def train(self):
        self.features = self.train_features
        self.labels = self.train_labels

    def eval(self):
        self.features = self.test_features
        self.labels = self.test_labels

    def shape(self):
        return Tensor(self.features).size(), Tensor(self.labels).size()

    def items(self):
        return Tensor(self.features), Tensor(self.labels)

    def __len__(self):
        return len(self.features) // self.batch_size

    def __getitem__(self, index):
        start = index * self.batch_size
        end = start + self.batch_size
        return Tensor(self.features[start: end]), Tensor(self.labels[start: end])

    @abstractmethod
    def estimate(self, predictions):
        pass

# %% [markdown]
# ### Base Layer

# %%
class Layer(ABC):

    def __init__(self):
        self.training = True

    def __call__(self, x: Tensor):
        return self.forward(x)

    def train(self):
        self.training = True

    def eval(self):
        self.training = False

    @abstractmethod
    def forward(self, x: Tensor):
        pass

    def parameters(self):
        return []

    def __str__(self):
        return ''

# %% [markdown]
# ### Base Loss Function

# %%
class Loss(ABC):

    @abstractmethod
    def __call__(self, p: Tensor, y: Tensor):
        pass

# %% [markdown]
# ### Base Optimizer

# %%
class Optimizer(ABC):

    def __init__(self, parameters, lr):
        self.parameters = parameters
        self.lr = lr

    @abstractmethod
    def backward(self):
        pass

# %% [markdown]
# ### Base Model

# %%
class Model(ABC):

    def __init__(self, layer, loss, optimizer):
        self.layer = layer
        self.loss = loss
        self.optimizer = optimizer

    @abstractmethod
    def train(self, dataset, epochs):
        pass

    @abstractmethod
    def test(self, dataset):
        pass

# %% [markdown]
# ## Data

# %% [markdown]
# ### RNN Dataset

# %%
class RNNDataset(Dataset):

    def __init__(self, filename):
        self.filename = filename
        super().__init__()

    def load(self):
        self.reviews = []
        self.sentiments = []
        with open(self.filename, 'r', encoding='utf-8') as f:
            reader = csv.reader(f)
            next(reader)
            for _, row in enumerate(reader):
                self.reviews.append(row[0])
                self.sentiments.append(row[1])

        split_reviews = []
        for line in self.reviews:
            split_reviews.append(self.clean_text(line.lower()).split())

        self.vocabulary = set(word for line in split_reviews for word in line)
        self.word2index = {word: index for index, word in enumerate(self.vocabulary)}
        self.index2word = {index: word for index, word in enumerate(self.vocabulary)}
        self.tokens = [[self.word2index[word] for word in line if word in self.word2index] for line in split_reviews]

    @staticmethod
    def clean_text(text):
        text = re.sub(r'<[^>]+>', '', text)
        text = re.sub(r'[^a-zA-Z0-9\s]', '', text)
        return text

    def train(self):
        self.features = []
        self.labels = []
        for line in self.tokens[:-10]:
            for index in range(len(line) - 4):
                self.features.append([line[index], line[index + 1], line[index + 3], line[index + 4]])
                self.labels.append(self.onehot(line[index + 2]))
    def eval(self):
        self.features = []
        self.labels = []
        for line in self.tokens[-10:]:
            for index in range(len(line) - 4):
                self.features.append([line[index], line[index + 1], line[index + 3], line[index + 4]])
                self.labels.append(self.onehot(line[index + 2]))

    def encode(self, text):
        words = self.clean_text(text.lower()).split()
        return [self.word2index[word] for word in words]

    def decode(self, tokens):
        return " ".join([self.index2word[index] for index in tokens])

    def onehot(self, token):
        ebd = np.zeros(len(self.vocabulary))
        ebd[token] = 1
        return ebd

    @staticmethod
    def argmax(vector):
        return [np.argmax(vector)]

    def estimate(self, predictions):
        count = 0
        for i in range(len(predictions)):
            if self.argmax(predictions[i].data[0]) == self.argmax(self.labels[i].data):
                count += 1
        return count / len(predictions)

# %% [markdown]
# ## Model

# %% [markdown]
# ### Linear Layer

# %%
class Linear(Layer):

    def __init__(self, in_size, out_size):
        super().__init__()
        self.weight = Tensor(np.random.rand(out_size, in_size) / in_size)
        self.bias = Tensor(np.zeros(out_size))

    def forward(self, x: Tensor):
        p = Tensor(x.data @ self.weight.data.T + self.bias.data)

        def gradient_fn():
            self.weight.grad = p.grad.T @ x.data / len(x.data)
            self.bias.grad = np.sum(p.grad, axis=0) / len(x.data)
            x.grad = p.grad @ self.weight.data

        p.gradient_fn = gradient_fn
        p.parents = {self.weight, self.bias, x}
        return p

    def parameters(self):
        return [self.weight, self.bias]

    def __str__(self):
        return f'weight: {self.weight}\nbias: {self.bias}'

# %% [markdown]
# ### Sequential Layer

# %%
class Sequential(Layer):

    def __init__(self, layers):
        super().__init__()
        self.layers = layers

    def train(self):
        for l in self.layers:
            l.train()

    def eval(self):
        for l in self.layers:
            l.eval()

    def forward(self, x: Tensor):
        for l in self.layers:
            x = l(x)
        return x

    def parameters(self):
        return [p for l in self.layers for p in l.parameters()]

    def __str__(self):
        return '\n'.join(str(l) for l in self.layers if str(l))

# %% [markdown]
# ### Embedding Layer

# %%
class Embedding(Layer):

    def __init__(self, vocabulary_size, embedding_size, axis=1):
        super().__init__()
        self.vocabulary_size = vocabulary_size
        self.embedding_size = embedding_size
        self.axis = axis

        self.weight = Tensor(np.random.rand(embedding_size, vocabulary_size) / vocabulary_size)

    def forward(self, x: Tensor):
        p = Tensor(np.sum(self.weight.data.T[x.data], axis=self.axis))

        def gradient_fn():
            if self.weight.grad is None:
                self.weight.grad = np.zeros_like(self.weight.data)
            self.weight.grad.T[x.data] += p.grad

        p.gradient_fn = gradient_fn
        p.parents = {self.weight}
        return p

    def parameters(self):
        return [self.weight]

# %% [markdown]
# ### ReLU Activation Function

# %%
class ReLU(Layer):

    def forward(self, x: Tensor):
        p = Tensor(np.maximum(0, x.data))

        def gradient_fn():
            x.grad = (p.data > 0) * p.grad

        p.gradient_fn = gradient_fn
        p.parents = {x}
        return p

# %% [markdown]
# ### Tanh Activation Function

# %%
class Tanh(Layer):

    def forward(self, x: Tensor):
        p = Tensor(np.tanh(x.data))

        def gradient_fn():
            x.grad = p.grad * (1 - p.data ** 2)

        p.gradient_fn = gradient_fn
        p.parents = {x}
        return p

# %% [markdown]
# ### Sigmoid Activation Function

# %%
class Sigmoid(Layer):

    def __init__(self, clip_range=(-100, 100)):
        super().__init__()
        self.clip_range = clip_range

    def forward(self, x: Tensor):
        z = np.clip(x.data, self.clip_range[0], self.clip_range[1])
        p = Tensor(1 / (1 + np.exp(-z)))

        def gradient_fn():
            x.grad = p.grad * p.data * (1 - p.data)

        p.gradient_fn = gradient_fn
        p.parents = {x}
        return p

# %% [markdown]
# ### Softmax Activation Function

# %%
class Softmax(Layer):

    def __init__(self, axis=1):
        super().__init__()
        self.axis = axis

    def forward(self, x: Tensor):
        exp = np.exp(x.data - np.max(x.data, axis=self.axis, keepdims=True))
        p = Tensor(exp / np.sum(exp, axis=self.axis, keepdims=True))

        def gradient_fn():
            x.grad = np.zeros_like(x.data)
            for idx in range(x.data.shape[0]):
                itm = p.data[idx].reshape(-1, 1)
                x.grad[idx] = (np.diagflat(itm) - itm @ itm.T) @ p.grad[idx]

        p.gradient_fn = gradient_fn
        p.parents = {x}
        return p

# %% [markdown]
# ### MSE Loss Function

# %%
class MSELoss(Loss):

    def __call__(self, p: Tensor, y: Tensor):
        mse = Tensor(((p.data - y.data) ** 2).mean())

        def gradient_fn():
            p.grad = (p.data - y.data) * 2

        mse.gradient_fn = gradient_fn
        mse.parents = {p}
        return mse

# %% [markdown]
# ### Cross Entropy Loss Function

# %%
class CELoss:

    def __call__(self, p: Tensor, y: Tensor):
        exp = np.exp(p.data - np.max(p.data, axis=-1, keepdims=True))
        softmax = exp / np.sum(exp, axis=-1, keepdims=True)

        log = np.log(np.clip(softmax, 1e-10, 1))
        ce = Tensor(0 - np.sum(y.data * log) / len(p.data))

        def gradient_fn():
            p.grad = (softmax - y.data) / len(p.data)

        ce.gradient_fn = gradient_fn
        ce.parents = {p}
        return ce

# %% [markdown]
# ### Binary Cross Entropy Loss Function

# %%
class BCELoss:

    def __call__(self, p: Tensor, y: Tensor):
        clipped = np.clip(p.data, 1e-7, 1 - 1e-7)
        bce = Tensor(-np.mean(y.data * np.log(clipped)
                              + (1 - y.data) * np.log(1 - clipped)))

        def gradient_fn():
            p.grad = (clipped - y.data) / (clipped * (1 - clipped)) * len(p.data)

        bce.gradient_fn = gradient_fn
        bce.parents = {p}
        return bce

# %% [markdown]
# ### SGD Optimizer

# %%
class SGDOptimizer(Optimizer):

    def backward(self):
        for p in self.parameters:
            p.data -= p.grad * self.lr

# %% [markdown]
# ### Recurrent Neural Network Model

# %%
class RNNModel(Model):

    def train(self, dataset, epochs):
        layer.train()
        dataset.train()

        for epoch in range(epochs):
            for i in range(len(dataset)):
                features, labels = dataset[i]

                predictions = self.layer(features)
                error = self.loss(predictions,
                                  labels)

                error.backward()
                self.optimizer.backward()

    def test(self, dataset):
        layer.eval()
        dataset.eval()

        predictions = []
        for i in range(len(dataset)):
            feature, label = dataset[i]
            predictions.append(self.layer(feature))
        return predictions

# %% [markdown]
# ## Configuration

# %% [markdown]
# ### Learning Rate

# %%
LEARNING_RATE = 0.01

# %% [markdown]
# ### Epoch

# %%
EPOCHS = 100

# %% [markdown]
# ## Training

# %% [markdown]
# ### Iteration Training

# %%
dataset = RNNDataset('reviews.csv')
layer = Sequential([Embedding(len(dataset.vocabulary), 64),
                    Tanh(),
                    Linear(64, 16),
                    Tanh(),
                    Linear(16, len(dataset.vocabulary))])
loss = CELoss()
optimizer = SGDOptimizer(layer.parameters(),
                         lr=LEARNING_RATE)

model = RNNModel(layer,
                 loss,
                 optimizer)
model.train(dataset,
            EPOCHS)

# %% [markdown]
# ## Testing

# %% [markdown]
# ### Estimating

# %%
predictions = model.test(dataset)

print(f'Accuracy: {dataset.estimate(predictions)}')
# Out:
# Accuracy: 0.4394904458598726

# %% [markdown]
# ### Comparing Labels and Predictions

# %%
features, labels = dataset.items()
for i in range(len(predictions)):
    pos = np.argmax(predictions[i].data[0])
    print(f'Feature: {dataset.decode(features.data[i])} | '
          f'Label: {dataset.decode(dataset.argmax(labels.data[i]))} | '
          f'Prediction: {dataset.decode(dataset.argmax(predictions[i].data[0]))}')
# Out:
# Feature: worst movie awful music | Label: with | Prediction: with
# Feature: movie with music the | Label: awful | Prediction: awful
# Feature: with awful the actor | Label: music | Prediction: soundtrack
# Feature: awful music actor did | Label: the | Prediction: the
# Feature: music the did a | Label: actor | Prediction: actor
# Feature: the actor a boring | Label: did | Prediction: did
# Feature: actor did boring job | Label: a | Prediction: a
# Feature: did a job actress | Label: boring | Prediction: poor
# Feature: a boring actress director | Label: job | Prediction: actress
# Feature: boring job director character | Label: actress | Prediction: actor
# Feature: job actress character screenplay | Label: director | Prediction: director
# Feature: actress director screenplay scene | Label: character | Prediction: character
# Feature: director character scene but | Label: screenplay | Prediction: actress
# Feature: character screenplay but or | Label: scene | Prediction: character
# Feature: screenplay scene or it | Label: but | Prediction: screenplay
# Feature: scene but it at | Label: or | Prediction: this
# Feature: but or at by | Label: it | Prediction: of
# Feature: i recommend film the | Label: this | Prediction: this
# Feature: recommend this the actress | Label: film | Prediction: film
# Feature: this film actress was | Label: the | Prediction: the
# Feature: film the was wonderful | Label: actress | Prediction: actor
# Feature: the actress wonderful and | Label: was | Prediction: actor
# Feature: actress was and the | Label: wonderful | Prediction: excellent
# Feature: was wonderful the music | Label: and | Prediction: character
# Feature: wonderful and music was | Label: the | Prediction: the
# Feature: and the was amazing | Label: music | Prediction: story
# Feature: the music amazing actor | Label: was | Prediction: and
# Feature: music was actor director | Label: amazing | Prediction: great
# Feature: was amazing director character | Label: actor | Prediction: character
# Feature: amazing actor character scene | Label: director | Prediction: actress
# Feature: actor director scene plot | Label: character | Prediction: actress
# Feature: director character plot by | Label: scene | Prediction: screenplay
# Feature: character scene by was | Label: plot | Prediction: actor
# Feature: poor movie story and | Label: the | Prediction: the
# Feature: movie the and actor | Label: story | Prediction: screenplay
# Feature: the story actor were | Label: and | Prediction: and
# Feature: story and were terrible | Label: actor | Prediction: screenplay
# Feature: and actor terrible i | Label: were | Prediction: were
# Feature: actor were i disappointed | Label: terrible | Prediction: terrible
# Feature: were terrible disappointed the | Label: i | Prediction: i
# Feature: terrible i the director | Label: disappointed | Prediction: i
# Feature: i disappointed director actress | Label: the | Prediction: the
# Feature: disappointed the actress character | Label: director | Prediction: and
# Feature: the director character action | Label: actress | Prediction: actress
# Feature: director actress action screenplay | Label: character | Prediction: actress
# Feature: actress character screenplay scene | Label: action | Prediction: plot
# Feature: character action scene by | Label: screenplay | Prediction: actor
# Feature: action screenplay by is | Label: scene | Prediction: was
# Feature: excellent film saw this | Label: i | Prediction: i
# Feature: film i this time | Label: saw | Prediction: saw
# Feature: i saw time perfect | Label: this | Prediction: this
# Feature: saw this perfect performance | Label: time | Prediction: time
# Feature: this time performance by | Label: perfect | Prediction: fantastic
# Feature: time perfect by the | Label: performance | Prediction: performance
# Feature: perfect performance the actor | Label: by | Prediction: by
# Feature: performance by actor and | Label: the | Prediction: the
# Feature: by the and actress | Label: actor | Prediction: actor
# Feature: the actor actress director | Label: and | Prediction: character
# Feature: actor and director screenplay | Label: actress | Prediction: screenplay
# Feature: and actress screenplay scene | Label: director | Prediction: director
# Feature: actress director scene character | Label: screenplay | Prediction: actress
# Feature: director screenplay character his | Label: scene | Prediction: actress
# Feature: screenplay scene his her | Label: character | Prediction: plot
# Feature: boring movie poor effect | Label: with | Prediction: the
# Feature: movie with effect the | Label: poor | Prediction: amazing
# Feature: with poor the director | Label: effect | Prediction: great
# Feature: poor effect director did | Label: the | Prediction: the
# Feature: effect the did a | Label: director | Prediction: director
# Feature: the director a awful | Label: did | Prediction: did
# Feature: director did awful job | Label: a | Prediction: a
# Feature: did a job actor | Label: awful | Prediction: awful
# Feature: a awful actor character | Label: job | Prediction: actress
# Feature: awful job character actress | Label: actor | Prediction: actor
# Feature: job actor actress screenplay | Label: character | Prediction: character
# Feature: actor character screenplay music | Label: actress | Prediction: scene
# Feature: character actress music plot | Label: screenplay | Prediction: scene
# Feature: actress screenplay plot by | Label: music | Prediction: screenplay
# Feature: screenplay music by was | Label: plot | Prediction: scene
# Feature: music plot was is | Label: by | Prediction: by
# Feature: this film wonderful i | Label: was | Prediction: was
# Feature: film was i loved | Label: wonderful | Prediction: amazing
# Feature: was wonderful loved the | Label: i | Prediction: i
# Feature: wonderful i the plot | Label: loved | Prediction: enjoyed
# Feature: i loved plot and | Label: the | Prediction: were
# Feature: loved the and actress | Label: plot | Prediction: actor
# Feature: the plot actress the | Label: and | Prediction: and
# Feature: plot and the scene | Label: actress | Prediction: character
# Feature: and actress scene was | Label: the | Prediction: the
# Feature: actress the was amazing | Label: scene | Prediction: actor
# Feature: the scene amazing director | Label: was | Prediction: and
# Feature: scene was director character | Label: amazing | Prediction: actor
# Feature: was amazing character actor | Label: director | Prediction: perfect
# Feature: amazing director actor screenplay | Label: character | Prediction: scene
# Feature: director character screenplay his | Label: actor | Prediction: actress
# Feature: character actor his her | Label: screenplay | Prediction: his
# Feature: great movie actor and | Label: the | Prediction: the
# Feature: movie the and screenplay | Label: actor | Prediction: actor
# Feature: the actor screenplay were | Label: and | Prediction: and
# Feature: actor and were excellent | Label: screenplay | Prediction: director
# Feature: and screenplay excellent i | Label: were | Prediction: the
# Feature: screenplay were i enjoyed | Label: excellent | Prediction: terrible
# Feature: were excellent enjoyed the | Label: i | Prediction: i
# Feature: excellent i the visual | Label: enjoyed | Prediction: enjoyed
# Feature: i enjoyed visual actress | Label: the | Prediction: the
# Feature: enjoyed the actress character | Label: visual | Prediction: and
# Feature: the visual character scene | Label: actress | Prediction: director
# Feature: visual actress scene script | Label: character | Prediction: director
# Feature: actress character script music | Label: scene | Prediction: story
# Feature: character scene music effect | Label: script | Prediction: actor
# Feature: scene script effect or | Label: music | Prediction: plot
# Feature: i waste time the | Label: of | Prediction: of
# Feature: waste of the screenplay | Label: time | Prediction: time
# Feature: of time screenplay was | Label: the | Prediction: the
# Feature: time the was boring | Label: screenplay | Prediction: acting
# Feature: the screenplay boring and | Label: was | Prediction: character
# Feature: screenplay was and the | Label: boring | Prediction: awful
# Feature: was boring the scene | Label: and | Prediction: and
# Feature: boring and scene was | Label: the | Prediction: the
# Feature: and the was awful | Label: scene | Prediction: story
# Feature: the scene awful actor | Label: was | Prediction: job
# Feature: scene was actor actress | Label: awful | Prediction: excellent
# Feature: was awful actress character | Label: actor | Prediction: terrible
# Feature: awful actor character screenplay | Label: actress | Prediction: character
# Feature: actor actress screenplay music | Label: character | Prediction: character
# Feature: actress character music effect | Label: screenplay | Prediction: actor
# Feature: character screenplay effect by | Label: music | Prediction: plot
# Feature: best film fantastic soundtrack | Label: with | Prediction: with
# Feature: film with soundtrack the | Label: fantastic | Prediction: boring
# Feature: with fantastic the director | Label: soundtrack | Prediction: music
# Feature: fantastic soundtrack director did | Label: the | Prediction: the
# Feature: soundtrack the did a | Label: director | Prediction: actor
# Feature: the director a perfect | Label: did | Prediction: did
# Feature: director did perfect job | Label: a | Prediction: a
# Feature: did a job actor | Label: perfect | Prediction: awful
# Feature: a perfect actor actress | Label: job | Prediction: did
# Feature: perfect job actress character | Label: actor | Prediction: actor
# Feature: job actor character scene | Label: actress | Prediction: actress
# Feature: actor actress scene screenplay | Label: character | Prediction: character
# Feature: actress character screenplay music | Label: scene | Prediction: actor
# Feature: character scene music in | Label: screenplay | Prediction: actor
# Feature: scene screenplay in on | Label: music | Prediction: at
# Feature: this movie terrible i | Label: was | Prediction: was
# Feature: movie was i hated | Label: terrible | Prediction: terrible
# Feature: was terrible hated the | Label: i | Prediction: i
# Feature: terrible i the story | Label: hated | Prediction: hated
# Feature: i hated story and | Label: the | Prediction: the
# Feature: hated the and actor | Label: story | Prediction: story
# Feature: the story actor the | Label: and | Prediction: and
# Feature: story and the scene | Label: actor | Prediction: actor
# Feature: and actor scene was | Label: the | Prediction: the
# Feature: actor the was poor | Label: scene | Prediction: and
# Feature: the scene poor actress | Label: was | Prediction: was
# Feature: scene was actress director | Label: poor | Prediction: character
# Feature: was poor director character | Label: actress | Prediction: actor
# Feature: poor actress character screenplay | Label: director | Prediction: character
# Feature: actress director screenplay action | Label: character | Prediction: actress
# Feature: director character action by | Label: screenplay | Prediction: actress
